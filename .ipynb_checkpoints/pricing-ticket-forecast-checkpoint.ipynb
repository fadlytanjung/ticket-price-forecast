# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 1: Prepare Features

# %% [markdown]
# #### Load and preprocess

# %%
df = pd.read_csv("ticket_price_dist.csv")
df['depart_date'] = pd.to_datetime(df['depart_date'])
df['route'] = df['airport_from'] + "_" + df['airport_to']

df = df.sort_values(['route', 'depart_date']).reset_index(drop=True)
df
# Out:
#        Unnamed: 0           extract_timestamp origin destination depart_date  \
# 0           30078  2022-12-29 03:13:11.798742   JKTC         BDJ  2023-01-01
# 1           30232  2022-12-31 01:49:22.466131   JKTC         BDJ  2023-01-01
# 2           30077  2022-12-29 03:13:11.798742   JKTC         BDJ  2023-01-02
# 3           30235  2022-12-31 01:49:22.466131   JKTC         BDJ  2023-01-02
# 4           30438  2023-01-02 00:37:44.519977   JKTC         BDJ  2023-01-02
# ...           ...                         ...    ...         ...         ...
# 45390       10995  2023-02-01 22:44:34.976945   JKTC         YIA  2023-07-29
# 45391       10807  2023-02-01 09:17:51.827188   JKTC         YIA  2023-07-30
# 45392       10987  2023-02-01 22:44:34.976945   JKTC         YIA  2023-07-30
# 45393       10809  2023-02-01 09:17:51.827188   JKTC         YIA  2023-07-31
# 45394       10989  2023-02-01 22:44:34.976945   JKTC         YIA  2023-07-31
#
#        best_price airport_from airport_to  distance_km  flight_time_hour  \
# 0       1414200.0          CGK        BDJ       946.44              2.02
# 1       1137800.0          CGK        BDJ       946.44              2.02
# 2       1345400.0          CGK        BDJ       946.44              2.02
# 3       1206600.0          CGK        BDJ       946.44              2.02
# 4       1348099.0          CGK        BDJ       946.44              2.02
# ...           ...          ...        ...          ...               ...
# 45390    495660.0          CGK        YIA       455.91              1.33
# 45391    475660.0          CGK        YIA       455.91              1.33
# 45392    495660.0          CGK        YIA       455.91              1.33
# 45393    475660.0          CGK        YIA       455.91              1.33
# 45394    495660.0          CGK        YIA       455.91              1.33
#
#       extract_date             time weekday_name  calendar_day  calendar_year  \
# 0       2022-12-29  03:13:11.798742       Sunday             1           2023
# 1       2022-12-31  01:49:22.466131       Sunday             1           2023
# 2       2022-12-29  03:13:11.798742       Monday             2           2023
# 3       2022-12-31  01:49:22.466131       Monday             2           2023
# 4       2023-01-02  00:37:44.519977       Monday             2           2023
# ...            ...              ...          ...           ...            ...
# 45390   2023-02-01  22:44:34.976945     Saturday            29           2023
# 45391   2023-02-01  09:17:51.827188       Sunday            30           2023
# 45392   2023-02-01  22:44:34.976945       Sunday            30           2023
# 45393   2023-02-01  09:17:51.827188       Monday            31           2023
# 45394   2023-02-01  22:44:34.976945       Monday            31           2023
#
#        calendar_month  week_number extraction_period    route
# 0                   1           52            3 days  CGK_BDJ
# 1                   1           52            1 days  CGK_BDJ
# 2                   1            1            4 days  CGK_BDJ
# 3                   1            1            2 days  CGK_BDJ
# 4                   1            1            0 days  CGK_BDJ
# ...               ...          ...               ...      ...
# 45390               7           30          178 days  CGK_YIA
# 45391               7           30          179 days  CGK_YIA
# 45392               7           30          179 days  CGK_YIA
# 45393               7           31          180 days  CGK_YIA
# 45394               7           31          180 days  CGK_YIA
#
# [45395 rows x 19 columns]

# %%
df["days_until_departure"] = (pd.to_datetime(df["depart_date"]) - pd.to_datetime(df["extract_date"])).dt.days
df
# Out:
#        Unnamed: 0           extract_timestamp origin destination depart_date  \
# 0           30078  2022-12-29 03:13:11.798742   JKTC         BDJ  2023-01-01
# 1           30232  2022-12-31 01:49:22.466131   JKTC         BDJ  2023-01-01
# 2           30077  2022-12-29 03:13:11.798742   JKTC         BDJ  2023-01-02
# 3           30235  2022-12-31 01:49:22.466131   JKTC         BDJ  2023-01-02
# 4           30438  2023-01-02 00:37:44.519977   JKTC         BDJ  2023-01-02
# ...           ...                         ...    ...         ...         ...
# 45390       10995  2023-02-01 22:44:34.976945   JKTC         YIA  2023-07-29
# 45391       10807  2023-02-01 09:17:51.827188   JKTC         YIA  2023-07-30
# 45392       10987  2023-02-01 22:44:34.976945   JKTC         YIA  2023-07-30
# 45393       10809  2023-02-01 09:17:51.827188   JKTC         YIA  2023-07-31
# 45394       10989  2023-02-01 22:44:34.976945   JKTC         YIA  2023-07-31
#
#        best_price airport_from airport_to  distance_km  flight_time_hour  \
# 0       1414200.0          CGK        BDJ       946.44              2.02
# 1       1137800.0          CGK        BDJ       946.44              2.02
# 2       1345400.0          CGK        BDJ       946.44              2.02
# 3       1206600.0          CGK        BDJ       946.44              2.02
# 4       1348099.0          CGK        BDJ       946.44              2.02
# ...           ...          ...        ...          ...               ...
# 45390    495660.0          CGK        YIA       455.91              1.33
# 45391    475660.0          CGK        YIA       455.91              1.33
# 45392    495660.0          CGK        YIA       455.91              1.33
# 45393    475660.0          CGK        YIA       455.91              1.33
# 45394    495660.0          CGK        YIA       455.91              1.33
#
#       extract_date             time weekday_name  calendar_day  calendar_year  \
# 0       2022-12-29  03:13:11.798742       Sunday             1           2023
# 1       2022-12-31  01:49:22.466131       Sunday             1           2023
# 2       2022-12-29  03:13:11.798742       Monday             2           2023
# 3       2022-12-31  01:49:22.466131       Monday             2           2023
# 4       2023-01-02  00:37:44.519977       Monday             2           2023
# ...            ...              ...          ...           ...            ...
# 45390   2023-02-01  22:44:34.976945     Saturday            29           2023
# 45391   2023-02-01  09:17:51.827188       Sunday            30           2023
# 45392   2023-02-01  22:44:34.976945       Sunday            30           2023
# 45393   2023-02-01  09:17:51.827188       Monday            31           2023
# 45394   2023-02-01  22:44:34.976945       Monday            31           2023
#
#        calendar_month  week_number extraction_period    route  \
# 0                   1           52            3 days  CGK_BDJ
# 1                   1           52            1 days  CGK_BDJ
# 2                   1            1            4 days  CGK_BDJ
# 3                   1            1            2 days  CGK_BDJ
# 4                   1            1            0 days  CGK_BDJ
# ...               ...          ...               ...      ...
# 45390               7           30          178 days  CGK_YIA
# 45391               7           30          179 days  CGK_YIA
# 45392               7           30          179 days  CGK_YIA
# 45393               7           31          180 days  CGK_YIA
# 45394               7           31          180 days  CGK_YIA
#
#        days_until_departure
# 0                         3
# 1                         1
# 2                         4
# 3                         2
# 4                         0
# ...                     ...
# 45390                   178
# 45391                   179
# 45392                   179
# 45393                   180
# 45394                   180
#
# [45395 rows x 20 columns]

# %% [markdown]
# #### Top Common Routes

# %%
# Find top 3 most common routes
top_routes = df['route'].value_counts().nlargest(3).index.tolist()

# Filter data for these routes
sample_df = df[df['route'].isin(top_routes)]

# Plot price over time for each route
plt.figure(figsize=(14, 6))
for route in top_routes:
    route_data = sample_df[sample_df['route'] == route]
    plt.plot(route_data['depart_date'], route_data['best_price'], label=route)

plt.title("Flight Ticket Prices Over Time for Top 3 Routes")
plt.xlabel("Departure Date")
plt.ylabel("Best Price (IDR)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Average price by weekday

# %%
import seaborn as sns

weekday_avg = df.groupby("weekday_name")["best_price"].mean().reindex(
    ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
)

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(x=weekday_avg.index, y=weekday_avg.values)
plt.title("Average Ticket Price by Weekday")
plt.ylabel("Average Price (IDR)")
plt.xticks(rotation=45)
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Top 10 routes by frequency

# %%
top_routes_freq = df['route'].value_counts().head(10)

plt.figure(figsize=(12, 5))
sns.barplot(x=top_routes_freq.index, y=top_routes_freq.values)
plt.title("Top 10 Most Frequent Routes")
plt.ylabel("Number of Records")
plt.xlabel("Route")
plt.xticks(rotation=45)
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Average monthly price trend

# %%
monthly_avg = df.groupby(["calendar_year", "calendar_month"])["best_price"].mean().reset_index()
monthly_avg['year_month'] = monthly_avg['calendar_year'].astype(str) + "-" + monthly_avg['calendar_month'].astype(str)

plt.figure(figsize=(14, 5))
plt.plot(monthly_avg['year_month'], monthly_avg['best_price'], marker='o')
plt.xticks(rotation=45)
plt.title("Average Ticket Price per Month")
plt.xlabel("Year-Month")
plt.ylabel("Avg Price (IDR)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Distance vs Price Correlation

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="distance_km", y="best_price", alpha=0.5)
plt.title("Distance vs Ticket Price")
plt.xlabel("Distance (km)")
plt.ylabel("Best Price (IDR)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Select Columns

# %%
features = [
    "distance_km",
    "flight_time_hour",
    "route",
]

target = "best_price"

# %% [markdown]
# #### Preprocessor

# %%
preprocessor = ColumnTransformer([
    ("num", MinMaxScaler(), [
        'flight_time_hour',
        'distance_km',
    ]),
    ("cat", OneHotEncoder(sparse_output=False), ['route'])
])
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', MinMaxScaler(),
#                                  ['flight_time_hour', 'distance_km']),
#                                 ('cat', OneHotEncoder(sparse_output=False),
#                                  ['route'])])

# %% [markdown]
# ### Step 2: Create multi-step squences

# %%
def create_multi_step_sequences_grouped(df, preprocessor, scaler_target, features, target, window_size=14, forecast_horizon=7):
    Xs, ys = [], []
    for _, group in df.groupby("route"):
        if len(group) < window_size + forecast_horizon:
            continue  # skip if not enough data
        X_group = preprocessor.transform(group[features])
        y_group = scaler_target.transform(group[[target]])
        for i in range(len(group) - window_size - forecast_horizon):
            Xs.append(X_group[i:i + window_size])
            ys.append(y_group[i + window_size:i + window_size + forecast_horizon])
    return np.array(Xs), np.array(ys)

# %% [markdown]
# ### Step 3: Preprocess & Split

# %%
# Transform features and target globally
X_all = preprocessor.fit_transform(df[features])
scaler_target = MinMaxScaler()
y_all = scaler_target.fit_transform(df[[target]])

# Generate sequences
WINDOW_SIZE = 28
FORECAST_HORIZON = 14

X_seq, y_seq = create_multi_step_sequences_grouped(df, preprocessor, scaler_target, features, target, WINDOW_SIZE, FORECAST_HORIZON)
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.3, shuffle=False)

# %% [markdown]
# ### Step 4: Multi-Step, Multi-Route LSTM

# %%
import tensorflow as tf

LSTM = tf.keras.layers.LSTM
Dense = tf.keras.layers.Dense
EarlyStopping = tf.keras.callbacks.EarlyStopping
ReduceLROnPlateau = tf.keras.callbacks.ReduceLROnPlateau
Sequential = tf.keras.models.Sequential
l2 = tf.keras.regularizers.l2
Dropout = tf.keras.layers.Dropout

model = Sequential([
    tf.keras.Input(shape=(WINDOW_SIZE, X_train.shape[2])),
    LSTM(64, return_sequences=True, kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    LSTM(32, kernel_regularizer=l2(0.001)),
    Dropout(0.3),
    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    Dense(FORECAST_HORIZON)
])

model.compile(optimizer='adam', loss='mse')
model.summary()

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=10,
    batch_size=32,
    callbacks=[
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
        #ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)
    ],
    verbose=1
)
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 64)             │        24,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 14)             │           910 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,646 (115.80 KB)
#  Trainable params: 29,646 (115.80 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 967/967 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0330 - val_loss: 0.0047
# Epoch 2/10
# 967/967 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0070 - val_loss: 0.0052
# Epoch 3/10
# 967/967 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0064 - val_loss: 0.0048
# Epoch 4/10
# 967/967 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0061 - val_loss: 0.0046
# Epoch 5/10
# 967/967 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0060 - val_loss: 0.0052
# Epoch 6/10
# 967/967 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 7/10
# 967/967 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 8/10
# 967/967 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 9/10
# 967/967 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0058 - val_loss: 0.0049
# Epoch 10/10
# 967/967 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0059 - val_loss: 0.0056

# %% [markdown]
# #### Evaluate MSE loss

# %%
plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.xlabel("Epoch")
plt.ylabel("Loss (MSE)")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 5: Evaluate & Plot

# %% [markdown]
# #### Predict and inverse scale

# %%
pred = model.predict(X_test)  # shape: (num_samples, forecast_horizon)

if y_test.ndim == 3:
    y_test = y_test.squeeze(-1)  # or use y_test = y_test.reshape(y_test.shape[0], -1)

pred_rescaled = scaler_target.inverse_transform(pred)
y_test_rescaled = scaler_target.inverse_transform(y_test)
print("pred shape:", pred.shape)
print("y_test shape (before):", y_test.shape)
# Out:
# 415/415 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# pred shape: (13254, 14)
# y_test shape (before): (13254, 14)

# %% [markdown]
# #### Plot first 1 prediction window

# %%
plt.figure(figsize=(10, 4))
plt.plot(y_test_rescaled[0], label='Actual')
plt.plot(pred_rescaled[0], label='Predicted')
plt.title("Multi-Step Price Forecast")
plt.xlabel("Day Ahead")
plt.ylabel("Price (IDR)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Rolling Forecast (Walk-Forward Strategy)

# %%
# Use the last window from X_test for rolling forecast
last_input = X_test[-1]  # shape: (WINDOW_SIZE, num_features)
rolling_input = last_input.copy()

# Predict one step at a time, feeding output back in
rolling_preds = []
for _ in range(FORECAST_HORIZON):
    inp = rolling_input.reshape(1, WINDOW_SIZE, -1)
    pred = model.predict(inp)[0][0]  # Get the first predicted value
    rolling_preds.append(pred)

    next_row = rolling_input[-1].copy()
    rolling_input = np.append(rolling_input[1:], [next_row], axis=0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# #### Inverse scale and plot

# %%
rolling_preds_rescaled = scaler_target.inverse_transform(np.array(rolling_preds).reshape(-1, 1))

plt.figure(figsize=(10, 4))
plt.plot(range(1, FORECAST_HORIZON + 1), rolling_preds_rescaled, marker='o', label='Forecasted Prices')
plt.title("Rolling Forecast: Next 14 Days")
plt.xlabel("Day Ahead")
plt.ylabel("Price (IDR)")
plt.legend()
plt.show()

# %%
def forecast_route(route_name: str, days_to_predict: int, df, model, preprocessor, scaler_target, window_size: int = 28):
    features = ["distance_km", "flight_time_hour", "route"]
    
    # Filter route-specific data
    route_df = df[df["route"] == route_name].copy()
    route_df = route_df.sort_values("depart_date")

    if len(route_df) < window_size:
        raise ValueError(f"Not enough data for route '{route_name}' (need at least {window_size} rows).")

    # Take the last `window_size` rows to make the initial window
    last_window = route_df[features].iloc[-window_size:].copy()

    forecasts = []
    for _ in range(days_to_predict):
        input_window = last_window.copy()
        input_window["route"] = route_name  # ensure route is consistent

        # Transform and reshape
        X_input = preprocessor.transform(input_window)
        X_input = X_input.reshape(1, window_size, -1)

        # Predict and inverse scale
        y_pred_scaled = model.predict(X_input)
        y_pred = scaler_target.inverse_transform(y_pred_scaled)
        forecasts.append(y_pred[0][0])

        # Simulate appending the prediction (optional, for rolling forecast)
        # Here we just repeat the last known row for continuity
        next_row = last_window.iloc[-1].copy()
        last_window = pd.concat([last_window.iloc[1:], pd.DataFrame([next_row])], ignore_index=True)

    return forecasts

# %%
predicted_prices = forecast_route(
    route_name="CGK_BDJ",
    days_to_predict=10,
    df=df,
    model=model,
    preprocessor=preprocessor,
    scaler_target=scaler_target,
    window_size=28
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
